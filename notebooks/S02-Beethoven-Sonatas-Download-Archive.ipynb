# %% [markdown]
# # Beethoven's Piano Sonatas: Automated Download and Archival
#
# ## An Introduction to Beethoven's Piano Sonatas
#
# Ludwig van Beethoven, a towering figure in the history of classical music, left an indelible mark on the world of piano composition. Among his vast oeuvre, the piano sonatas stand out as a testament to his genius, innovation, and expressiveness. Spanning his early, middle, and late periods, these works encapsulate the evolution of his style and the depth of his emotional expression.
#
# Beethoven's piano sonatas are not just a series of compositions; they are a journey through his life. From the early sonatas, which bear the influence of his predecessors like Mozart and Haydn, to the later ones, where he broke free from classical conventions and ventured into new territories of form and expression, each piece tells a story. They reflect his struggles, joys, introspections, and his relentless pursuit of artistic perfection.
#
# The "Pathétique" (Op. 13) with its dramatic contrasts, the "Moonlight" (Op. 27 No. 2) with its hauntingly beautiful Adagio, and the challenging "Hammerklavier" (Op. 106) are just a few examples that showcase the range and depth of Beethoven's creativity. Each sonata, whether it's the stormy "Tempest" (Op. 31 No. 2) or the radiant "Waldstein" (Op. 53), offers listeners a unique experience, a glimpse into Beethoven's soul.
#
# For pianists, these sonatas are both a challenge and a reward. They demand technical prowess, deep understanding, and emotional connectivity. For listeners, they offer a rich tapestry of melodies, themes, and emotions that resonate across time.
#
# In this collection, we present all of Beethoven's piano sonatas, a musical journey that spans his entire career. Whether you're a seasoned aficionado or a new listener, these works are a testament to the enduring power and beauty of Beethoven's musical legacy.

# %% [markdown]
# Website: https://www.suzumidi.com/eng/beethov1.htm
#
# | Folder Name | Title                                                      | File                           | Size KB | Time  |
# |-------------|------------------------------------------------------------|--------------------------------|---------|-------|
# | ps01        | Piano Sonata No.1 F Minor Op.2-1                           | ../midi/beethovn/ps01.zip      | 17.0    | 15:06 |
# | ps02        | Piano Sonata No.2 A Major Op.2-2                           | ../midi/beethovn/ps02.zip      | 21.4    | 20:56 |
# | ps03        | Piano Sonata No.3 C Major Op.2-3                           | ../midi/beethovn/ps03.zip      | 26.1    | 23:18 |
# | ps04        | Piano Sonata No.4 Ef Major Op.7                            | ../midi/beethovn/ps04.zip      | 28.6    | 24:43 |
# | ps05        | Piano Sonata No.5 C Minor Op.10-1                          | ../midi/beethovn/ps05.zip      | 16.3    | 14:37 |
# | ps06        | Piano Sonata No.6 F Major Op.10-2                          | ../midi/beethovn/ps06.zip      | 16.0    | 10:55 |
# | ps07        | Piano Sonata No.7 D Major Op.10-3                          | ../midi/beethovn/ps07.zip      | 23.5    | 20:58 |
# | ps08        | Piano Sonata No.8 C Minor Op.13 "Pathetic"                 | ../midi/beethovn/ps08.zip      | 19.3    | 15:44 |
# | ps09        | Piano Sonata No.9 E Major Op.14-1                          | ../midi/beethovn/ps09.zip      | 13.1    | 13:13 |
# | ps10        | Piano Sonata No.10 G Major Op.14-2                         | ../midi/beethovn/ps10.zip      | 15.3    | 15:01 |
# | ps11        | Piano Sonata No.11 B Major Op.22                           | ../midi/beethovn/ps11.zip      | 27.1    | 22:12 |
# | ps12        | Piano Sonata No.12 Af Major Op.26                          | ../midi/beethovn/ps12.zip      | 16.7    | 16:03 |
# | ps13        | Piano Sonata No.13 Ef Major Op.27-1                        | ../midi/beethovn/ps13.zip      | 15.7    | 13:46 |
# | ps14        | Piano Sonata No.14 Cs Minor Op.27-2 "Moon Light"           | ../midi/beethovn/ps14.zip      | 15.8    | 14:23 |
# | ps15        | Piano Sonata No.15 D Major Op.28 "Pastoral"                | ../midi/beethovn/ps15.zip      | 24.3    | 21:42 |
# | ps16        | Piano Sonata No.16 G Major Op.31-1                         | ../midi/beethovn/ps16.zip      | 25.2    | 20:15 |
# | ps17        | Piano Sonata No.17 D Minor Op.31-2 "Tempest"               | ../midi/beethovn/ps17.zip      | 20.3    | 21:25 |
# | ps18        | Piano Sonata No.18 Ef Major Op.31-3                        | ../midi/beethovn/ps18.zip      | 19.7    | 22:27 |
# | ps19        | Piano Sonata No.19 G Minor Op.49-1                         | ../midi/beethovn/ps19.zip      | 7.3     | 8:09  |
# | ps20        | Piano Sonata No.20 G Major Op.49-2                         | ../midi/beethovn/ps20.zip      | 6.4     | 7:33  |
# | ps21        | Piano Sonata No.21 C Major Op.53 "Waldstein"               | ../midi/beethovn/ps21.zip      | 36.6    | 22:41 |
# | ps22        | Piano Sonata No.22 F Major Op.54                           | ../midi/beethovn/ps22.zip      | 13.3    | 10:40 |
# | ps23        | Piano Sonata No.23 F Minor Op.57 "Apassionata"             | ../midi/beethovn/ps23.zip      | 35.6    | 22:17 |
# | ps24        | Piano Sonata No.24 Fs Major Op.78                          | ../midi/beethovn/ps24.zip      | 12.1    | 9:00  |
# | ps25        | Piano Sonata No.25 G Major Op.79                           | ../midi/beethovn/ps25.zip      | 9.6     | 9:03  |
# | ps26        | Piano Sonata No.26 Ef Major Op.81a "Les Adieux"            | ../midi/beethovn/ps26.zip      | 19.6    | 14:02 |
# | ps27        | Piano Sonata No.27 E Minor Op.90                           | ../midi/beethovn/ps27.zip      | 16.2    | 12:04 |
# | ps28        | Piano Sonata No.28 A Major Op.101                          | ../midi/beethovn/ps28.zip      | 24.0    | 18:29 |
# | ps29        | Piano Sonata No.29 B Major Op.106 "Hammerklavier"          | ../midi/beethovn/ps29.zip      | 58.1    | 37:21 |
# | ps30        | Piano Sonata No.30 E Major Op.109                          | ../midi/beethovn/ps30.zip      | 22.2    | 16:28 |
# | ps31        | Piano Sonata No.31 Af Major Op.110                         | ../midi/beethovn/ps31.zip      | 20.5    | 16:19 |
# | ps32        | Piano Sonata No.32 C Minor Op.111                          | ../midi/beethovn/ps32.zip      | 28.8    | 23:49 |
# | ps33        | Kurfsten Sonata No.1 in Eb Major WoO 47-1                  | ../midi/beethovn/ps33.zip      | 10.7    | 9:14  |
# | ps34        | Kurfsten Sonata No.2 in F Minor WoO 47-2                   | ../midi/beethovn/ps34.zip      | 10.8    | 11:35 |
# | ps35        | Kurfsten Sonata No.3 in D Major WoO 47-3                   | ../midi/beethovn/ps35.zip      | 12.4    | 15:43 |

# %% [markdown]
# ## Scrape the webpage
#
#
# The code is designed to automatically download and extract a series of
# ZIP files containing MIDI compositions of Beethoven's piano sonatas from
# a specified website.
#
# 1. **Setting Up the Environment**:
#     - The code begins by importing necessary libraries: `requests` for
#       downloading files from the web, `os` for directory and file
#       operations, and `zipfile` for handling ZIP files.
#
# 2. **Defining URLs and Directories**:
#     - The base URL `https://www.suzumidi.com/midi/beethovn/` is where
#       the ZIP files are hosted.
#     - A list of filenames (`file_names`) is generated using a list
#       comprehension. This list contains filenames in the format
#       `psXX.zip`, where `XX` ranges from `01` to `39`, representing the
#       39 ZIP files to be downloaded.
#     - Two directories are defined: `download_directory` for saving the
#       downloaded ZIP files and `unzip_directory` for saving the
#       extracted contents of these ZIP files.
#
# 3. **Preparing the Filesystem**:
#     - The code checks if the directories `download_directory` and
#       `unzip_directory` exist. If they don't, the code creates them.
#
# 4. **Downloading and Extracting Files**:
#     - For each filename in the `file_names` list:
#         - The full URL of the file is constructed by appending the
#           filename to the base URL.
#         - The file is then downloaded using the `requests.get()` method.
#           The response is streamed to handle potentially large files
#           without consuming excessive memory.
#         - If the download is successful (HTTP status code 200), the file
#           is saved to the `download_directory`.
#         - The saved ZIP file is then extracted using the
#           `zipfile.ZipFile` class, and its contents are saved to the
#           `unzip_directory`.
#         - A message is printed to the console indicating the progress
#           (whether a file was successfully downloaded and extracted or
#           if there was a failure).
#
# 5. **Completion**:
#     - Once all files have been processed, a message is printed to
#       indicate that the operation is complete.

# %%
import requests
import os
import zipfile

# Base URL
base_url = "https://www.suzumidi.com/midi/beethovn/"

# List of file names
file_names = [f"ps{i:02}.zip" for i in range(1, 40)]

# Directory to save the downloaded zip files
download_directory = "downloaded_files"

# Directory to save the unzipped files
unzip_directory = "../data/external"

# Ensure the directories exist
if not os.path.exists(download_directory):
    os.makedirs(download_directory)
    
if not os.path.exists(unzip_directory):
    os.makedirs(unzip_directory)

# Download and unzip each file
for file_name in file_names:
    # Construct the full URL
    full_url = base_url + file_name
    
    # Download the file
    response = requests.get(full_url, stream=True)
    if response.status_code == 200:
        # Save the file to the directory
        file_path = os.path.join(download_directory, file_name)
        with open(file_path, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        
        # Unzip the file to the specified location
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(unzip_directory)
        
        print(f"Downloaded and extracted {file_name}")
    else:
        print(f"Failed to download {file_name}")

print("All files processed.")
# Out:
# Downloaded and extracted ps01.zip
# Downloaded and extracted ps02.zip
# Downloaded and extracted ps03.zip
# Downloaded and extracted ps04.zip
# Downloaded and extracted ps05.zip
# Downloaded and extracted ps06.zip
# Downloaded and extracted ps07.zip
# Downloaded and extracted ps08.zip
# Downloaded and extracted ps09.zip
# Downloaded and extracted ps10.zip
# Downloaded and extracted ps11.zip
# Downloaded and extracted ps12.zip
# Downloaded and extracted ps13.zip
# Downloaded and extracted ps14.zip
# Downloaded and extracted ps15.zip
# Downloaded and extracted ps16.zip
# Downloaded and extracted ps17.zip
# Downloaded and extracted ps18.zip
# Downloaded and extracted ps19.zip
# Downloaded and extracted ps20.zip
# Downloaded and extracted ps21.zip
# Downloaded and extracted ps22.zip
# Downloaded and extracted ps23.zip
# Downloaded and extracted ps24.zip
# Downloaded and extracted ps25.zip
# Downloaded and extracted ps26.zip
# Downloaded and extracted ps27.zip
# ...
